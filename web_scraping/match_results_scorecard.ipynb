# %% [markdown]
# This Notebook is used to demonstrate a Python script that extracts indian-premier-league data from a https://www.espncricinfo.com/ using web scraping techniques.
# It leverages the requests library to fetch HTML content and BeautifulSoup to parse and extract the desired information.
# At the end we have download the fetched data as a CSV file.
#
# Click [link](https://www.espncricinfo.com/records/trophy/team-match-results/indian-premier-league-117) to visit the source page(Official ESPN).

# %%
from bs4 import BeautifulSoup
import pandas as pd

import requests

# %%
def get_tables(url):
    try :
        # Send an HTTP GET request to the website
        response = requests.get(url)

        # Parse the HTML code using BeautifulSoup
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.select('title')[0].get_text()
        match_id = url.split('/')[-2].split('-')[-1]
        
        print("Fetch data for :", title) 
        print("With Match_id :", match_id)

    except OSError :
        print("Check Your Internet!")

    except :
        raise Exception("Sorry!") 
        
    
    table_list = soup.select('table thead tr')
    main_column = []

    for table in table_list:
        list_items = [ items.get_text() for items in table.select('th') ]
        main_column.append(list_items)
        # print(list_items)

    # print(main_column)
    
    table_list = soup.select('table tbody')

    main_table = []
    for table in table_list:
        record = []

        for row in table.select('tr'):
            item_list = [ items.get_text() for items in row.select('td')]
            if len(item_list) <= 2 :
                continue
            record.append(item_list)

        main_table.append(record)
    # len(main_table)
    
    batting_1 = pd.DataFrame(main_table[0], columns = main_column[0])
    bowling_1 = pd.DataFrame(main_table[1], columns = main_column[1])
    batting_2 = pd.DataFrame(main_table[2], columns = main_column[2])
    bowling_2 = pd.DataFrame(main_table[3], columns = main_column[3])
    
    batting_1['match_id'] = match_id
    bowling_1['match_id'] = match_id
    batting_2['match_id'] = match_id
    bowling_2['match_id'] = match_id
    
    point_table = pd.DataFrame(main_table[8], columns = main_column[7])
    point_table['match_id'] = match_id
    
    return batting_1, bowling_1, batting_2, bowling_2, point_table

# %%
url = "https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-chennai-super-kings-final-1370353/full-scorecard"
batting_1, bowling_1, batting_2, bowling_2, point_table = get_tables(url)
# Out:
# Fetch data for : GT vs CSK, Indian Premier League 2023, Final at Ahmedabad, May 28 - 29, 2023 - Full Scorecard
# With Match_id : 1370353

# %%
batting_1.head(7)
# Out:
#              BATTING                             R   B     M    4s    6s  \
# 0  Wriddhiman Saha †      c †Dhoni b Chahar     54  39    63     5     1
# 1      Shubman Gill      st †Dhoni b Jadeja     39  20    34     7     0
# 2     Sai Sudharsan         lbw b Pathirana     96  47    58     8     6
# 3  Hardik Pandya (c)               not out      21  12    32     0     2
# 4       Rashid Khan   c Gaikwad b Pathirana      0   2     2     0     0
# 5             Extras       (b 1, lb 1, w 2)      4      None  None  None
# 6              TOTAL      20 Ov (RR: 10.70)  214/4      None  None  None
#
#        SR match_id
# 0  138.46  1370353
# 1  195.00  1370353
# 2  204.25  1370353
# 3  175.00  1370353
# 4    0.00  1370353
# 5    None  1370353
# 6    None  1370353

# %%
match_results_df = pd.read_csv("ipl_match_results.csv")
match_results_df.head()
# Out:
#          team_1       team_2       winner     margin     ground    match_date  \
# 0        Titans  Super Kings  Super Kings  5 wickets  Ahmedabad  May 28, 2023
# 1        Titans       Mumbai       Titans    62 runs  Ahmedabad  May 26, 2023
# 2  Super Giants       Mumbai       Mumbai    81 runs    Chennai  May 24, 2023
# 3   Super Kings       Titans  Super Kings    15 runs    Chennai  May 23, 2023
# 4           RCB       Titans       Titans  6 wickets  Bengaluru  May 21, 2023
#
#                                            scorecard  match_id
# 0  /series/indian-premier-league-2023-1345038/guj...   1370353
# 1  /series/indian-premier-league-2023-1345038/guj...   1370352
# 2  /series/indian-premier-league-2023-1345038/luc...   1370351
# 3  /series/indian-premier-league-2023-1345038/che...   1370350
# 4  /series/indian-premier-league-2023-1345038/roy...   1359544

# %%
scorecard_links = match_results_df.scorecard.tolist()
scorecard_links = [ "https://www.espncricinfo.com" + link for link in scorecard_links ]
scorecard_links[:3]
# Out:
# ['https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-chennai-super-kings-final-1370353/full-scorecard',
#  'https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/gujarat-titans-vs-mumbai-indians-qualifier-2-1370352/full-scorecard',
#  'https://www.espncricinfo.com/series/indian-premier-league-2023-1345038/lucknow-super-giants-vs-mumbai-indians-eliminator-1370351/full-scorecard']

# %%
batting_1, bowling_1, batting_2, bowling_2, point_table = get_tables(scorecard_links[72])
batting_1.head(7)
# Out:
# Fetch data for : PBKS vs KKR, Indian Premier League 2023, 2nd Match at Chandigarh, April 01, 2023 - Full Scorecard
# With Match_id : 1359476
#               BATTING                                    R   B   M 4s 6s  \
# 0  Prabhsimran Singh   c †Rahmanullah Gurbaz b Southee  23  12  10  2  2
# 1  Shikhar Dhawan (c)                          b Varun  40  29  75  6  0
# 2  Bhanuka Rajapaksa                   c Singh b Yadav  50  32  47  5  2
# 3     Jitesh Sharma †                c Yadav b Southee  21  11  13  1  2
# 4      Sikandar Raza                   c Rana b Narine  16  13  22  1  1
# 5         Sam Curran                          not out   26  17  27  0  2
# 6    M Shahrukh Khan                          not out   11   7  11  2  0
#
#        SR match_id
# 0  191.66  1359476
# 1  137.93  1359476
# 2  156.25  1359476
# 3  190.90  1359476
# 4  123.07  1359476
# 5  152.94  1359476
# 6  157.14  1359476

# %%
print("Total No of Matches :")
len(scorecard_links)
# Out:
# Total No of Matches :
# 1025

# %%
match_results_df.query("winner == 'no result'")
# Out:
#            team_1       team_2     winner margin     ground    match_date  \
# 29   Super Giants  Super Kings  no result      -    Lucknow   May 3, 2023
# 279           RCB       Royals  no result      -  Bengaluru  Apr 30, 2019
# 512           RCB   Daredevils  no result      -  Bengaluru  May 17, 2015
# 538           RCB       Royals  no result      -  Bengaluru  Apr 29, 2015
# 744           RCB  Super Kings  no result      -  Bengaluru  Apr 25, 2012
# 783    Daredevils     Warriors  no result      -      Delhi  May 21, 2011
#
#                                              scorecard  match_id
# 29   /series/indian-premier-league-2023-1345038/luc...   1359519
# 279  /series/ipl-2019-1165643/royal-challengers-ban...   1178424
# 512  /series/pepsi-indian-premier-league-2015-79112...    829813
# 538  /series/pepsi-indian-premier-league-2015-79112...    829763
# 744  /series/indian-premier-league-2012-520932/roya...    548340
# 783  /series/indian-premier-league-2011-466304/delh...    501265

# %%
match_results_df = match_results_df.query("winner != 'no result'")
scorecard_links = match_results_df.scorecard.tolist()
scorecard_links = [ "https://www.espncricinfo.com" + link for link in scorecard_links ]

print("Total No of Matches :")
len(scorecard_links)
# Out:
# Total No of Matches :
# 1019

# %%
match_results_df[match_results_df.match_date.str.contains('2023')]
# Out:
#           team_1       team_2        winner     margin     ground  \
# 0         Titans  Super Kings   Super Kings  5 wickets  Ahmedabad
# 1         Titans       Mumbai        Titans    62 runs  Ahmedabad
# 2   Super Giants       Mumbai        Mumbai    81 runs    Chennai
# 3    Super Kings       Titans   Super Kings    15 runs    Chennai
# 4            RCB       Titans        Titans  6 wickets  Bengaluru
# ..           ...          ...           ...        ...        ...
# 69           RCB       Mumbai           RCB  8 wickets  Bengaluru
# 70     Sunrisers       Royals        Royals    72 runs  Hyderabad
# 71  Super Giants     Capitals  Super Giants    50 runs    Lucknow
# 72  Punjab Kings          KKR  Punjab Kings     7 runs     Mohali
# 73        Titans  Super Kings        Titans  5 wickets  Ahmedabad
#
#       match_date                                          scorecard  match_id
# 0   May 28, 2023  /series/indian-premier-league-2023-1345038/guj...   1370353
# 1   May 26, 2023  /series/indian-premier-league-2023-1345038/guj...   1370352
# 2   May 24, 2023  /series/indian-premier-league-2023-1345038/luc...   1370351
# 3   May 23, 2023  /series/indian-premier-league-2023-1345038/che...   1370350
# 4   May 21, 2023  /series/indian-premier-league-2023-1345038/roy...   1359544
# ..           ...                                                ...       ...
# 69   Apr 2, 2023  /series/indian-premier-league-2023-1345038/roy...   1359479
# 70   Apr 2, 2023  /series/indian-premier-league-2023-1345038/sun...   1359478
# 71   Apr 1, 2023  /series/indian-premier-league-2023-1345038/luc...   1359477
# 72   Apr 1, 2023  /series/indian-premier-league-2023-1345038/pun...   1359476
# 73  Mar 31, 2023  /series/indian-premier-league-2023-1345038/guj...   1359475
#
# [73 rows x 8 columns]

# %%
# fetching data for recent 
batting_1 = pd.DataFrame()
bowling_1 = pd.DataFrame()
batting_2 = pd.DataFrame()
bowling_2 = pd.DataFrame()
point_table = pd.DataFrame()
for each_match in scorecard_links[:73]:
    batting_1t, bowling_1t, batting_2t, bowling_2t, point_table_t = get_tables(each_match)
    
    batting_1 = pd.concat([batting_1, batting_1t])
    bowling_1 = pd.concat([bowling_1, bowling_1t])
    batting_2 = pd.concat([batting_2, batting_2t])
    bowling_2 = pd.concat([bowling_2, bowling_2t])
    point_table = pd.concat([point_table, point_table_t])
    
# print(f"Data fetch for {} Total No of Matchs")
# Out:
# Fetch data for : GT vs CSK, Indian Premier League 2023, Final at Ahmedabad, May 28 - 29, 2023 - Full Scorecard
# With Match_id : 1370353
# Fetch data for : GT vs MI, Indian Premier League 2023, Qualifier 2 at Ahmedabad, May 26, 2023 - Full Scorecard
# With Match_id : 1370352
# Fetch data for : LSG vs MI, Indian Premier League 2023, Eliminator at Chennai, May 24, 2023 - Full Scorecard
# With Match_id : 1370351
# Fetch data for : CSK vs GT, Indian Premier League 2023, Qualifier 1 at Chennai, May 23, 2023 - Full Scorecard
# With Match_id : 1370350
# Fetch data for : RCB vs GT, Indian Premier League 2023, 70th Match at Bengaluru, May 21, 2023 - Full Scorecard
# With Match_id : 1359544
# Fetch data for : MI vs SRH, Indian Premier League 2023, 69th Match at Mumbai, May 21, 2023 - Full Scorecard
# With Match_id : 1359543
# Fetch data for : KKR vs LSG, Indian Premier League 2023, 68th Match at Kolkata, May 20, 2023 - Full Scorecard
# With Match_id : 1359542
# Fetch data for : DC vs CSK, Indian Premier League 2023, 67th Match at Delhi, May 20, 2023 - Full Scorecard
# With Match_id : 1359541
# Fetch data for : PBKS vs RR, Indian Premier League 2023, 66th Match at Dharamsala, May 19, 2023 - Full Scorecard
# With Match_id : 1359540
# Fetch data for : SRH vs RCB, Indian Premier League 2023, 65th Match at Hyderabad, May 18, 2023 - Full Scorecard
# With Match_id : 1359539
# Fetch data for : PBKS vs DC, Indian Premier League 2023, 64th Match at Dharamsala, May 17, 2023 - Full Scorecard
# With Match_id : 1359538
# Fetch data for : LSG vs MI, Indian Premier League 2023, 63rd Match at Lucknow, May 16, 2023 - Full Scorecard
# With Match_id : 1359537
# Fetch data for : GT vs SRH, Indian Premier League 2023, 62nd Match at Ahmedabad, May 15, 2023 - Full Scorecard
# With Match_id : 1359536
# Fetch data for : CSK vs KKR, Indian Premier League 2023, 61st Match at Chennai, May 14, 2023 - Full Scorecard
# With Match_id : 1359535
# Fetch data for : RR vs RCB, Indian Premier League 2023, 60th Match at Jaipur, May 14, 2023 - Full Scorecard
# With Match_id : 1359534
# Fetch data for : DC vs PBKS, Indian Premier League 2023, 59th Match at Delhi, May 13, 2023 - Full Scorecard
# With Match_id : 1359533
# Fetch data for : SRH vs LSG, Indian Premier League 2023, 58th Match at Hyderabad, May 13, 2023 - Full Scorecard
# With Match_id : 1359532
# Fetch data for : MI vs GT, Indian Premier League 2023, 57th Match at Mumbai, May 12, 2023 - Full Scorecard
# With Match_id : 1359531
# Fetch data for : KKR vs RR, Indian Premier League 2023, 56th Match at Kolkata, May 11, 2023 - Full Scorecard
# With Match_id : 1359530
# Fetch data for : CSK vs DC, Indian Premier League 2023, 55th Match at Chennai, May 10, 2023 - Full Scorecard
# With Match_id : 1359529
# Fetch data for : MI vs RCB, Indian Premier League 2023, 54th Match at Mumbai, May 09, 2023 - Full Scorecard
# With Match_id : 1359528
# Fetch data for : KKR vs PBKS, Indian Premier League 2023, 53rd Match at Kolkata, May 08, 2023 - Full Scorecard
# With Match_id : 1359527
# Fetch data for : RR vs SRH, Indian Premier League 2023, 52nd Match at Jaipur, May 07, 2023 - Full Scorecard
# With Match_id : 1359526
# Fetch data for : GT vs LSG, Indian Premier League 2023, 51st Match at Ahmedabad, May 07, 2023 - Full Scorecard
# With Match_id : 1359525
# Fetch data for : DC vs RCB, Indian Premier League 2023, 50th Match at Delhi, May 06, 2023 - Full Scorecard
# With Match_id : 1359524
# Fetch data for : CSK vs MI, Indian Premier League 2023, 49th Match at Chennai, May 06, 2023 - Full Scorecard
# With Match_id : 1359523
# Fetch data for : RR vs GT, Indian Premier League 2023, 48th Match at Jaipur, May 05, 2023 - Full Scorecard
# With Match_id : 1359522
# Fetch data for : SRH vs KKR, Indian Premier League 2023, 47th Match at Hyderabad, May 04, 2023 - Full Scorecard
# With Match_id : 1359521
# Fetch data for : PBKS vs MI, Indian Premier League 2023, 46th Match at Chandigarh, May 03, 2023 - Full Scorecard
# With Match_id : 1359520
# Fetch data for : GT vs DC, Indian Premier League 2023, 44th Match at Ahmedabad, May 02, 2023 - Full Scorecard
# With Match_id : 1359518
# Fetch data for : LSG vs RCB, Indian Premier League 2023, 43rd Match at Lucknow, May 01, 2023 - Full Scorecard
# With Match_id : 1359517
# Fetch data for : MI vs RR, Indian Premier League 2023, 42nd Match at Mumbai, April 30, 2023 - Full Scorecard
# With Match_id : 1359516
# Fetch data for : CSK vs PBKS, Indian Premier League 2023, 41st Match at Chennai, April 30, 2023 - Full Scorecard
# With Match_id : 1359515
# Fetch data for : DC vs SRH, Indian Premier League 2023, 40th Match at Delhi, April 29, 2023 - Full Scorecard
# With Match_id : 1359514
# Fetch data for : KKR vs GT, Indian Premier League 2023, 39th Match at Kolkata, April 29, 2023 - Full Scorecard
# With Match_id : 1359513
# Fetch data for : PBKS vs LSG, Indian Premier League 2023, 38th Match at Chandigarh, April 28, 2023 - Full Scorecard
# With Match_id : 1359512
# Fetch data for : RR vs CSK, Indian Premier League 2023, 37th Match at Jaipur, April 27, 2023 - Full Scorecard
# With Match_id : 1359511
# Fetch data for : RCB vs KKR, Indian Premier League 2023, 36th Match at Bengaluru, April 26, 2023 - Full Scorecard
# With Match_id : 1359510
# Fetch data for : GT vs MI, Indian Premier League 2023, 35th Match at Ahmedabad, April 25, 2023 - Full Scorecard
# With Match_id : 1359509
# Fetch data for : SRH vs DC, Indian Premier League 2023, 34th Match at Hyderabad, April 24, 2023 - Full Scorecard
# With Match_id : 1359508
# Fetch data for : KKR vs CSK, Indian Premier League 2023, 33rd Match at Kolkata, April 23, 2023 - Full Scorecard
# With Match_id : 1359507
# Fetch data for : RCB vs RR, Indian Premier League 2023, 32nd Match at Bengaluru, April 23, 2023 - Full Scorecard
# With Match_id : 1359506
# Fetch data for : MI vs PBKS, Indian Premier League 2023, 31st Match at Mumbai, April 22, 2023 - Full Scorecard
# With Match_id : 1359505
# Fetch data for : LSG vs GT, Indian Premier League 2023, 30th Match at Lucknow, April 22, 2023 - Full Scorecard
# With Match_id : 1359504
# Fetch data for : CSK vs SRH, Indian Premier League 2023, 29th Match at Chennai, April 21, 2023 - Full Scorecard
# With Match_id : 1359503
# Fetch data for : DC vs KKR, Indian Premier League 2023, 28th Match at Delhi, April 20, 2023 - Full Scorecard
# With Match_id : 1359502
# Fetch data for : PBKS vs RCB, Indian Premier League 2023, 27th Match at Chandigarh, April 20, 2023 - Full Scorecard
# With Match_id : 1359501
# Fetch data for : RR vs LSG, Indian Premier League 2023, 26th Match at Jaipur, April 19, 2023 - Full Scorecard
# With Match_id : 1359500
# Fetch data for : SRH vs MI, Indian Premier League 2023, 25th Match at Hyderabad, April 18, 2023 - Full Scorecard
# With Match_id : 1359499
# Fetch data for : RCB vs CSK, Indian Premier League 2023, 24th Match at Bengaluru, April 17, 2023 - Full Scorecard
# With Match_id : 1359498
# Fetch data for : GT vs RR, Indian Premier League 2023, 23rd Match at Ahmedabad, April 16, 2023 - Full Scorecard
# With Match_id : 1359497
# Fetch data for : MI vs KKR, Indian Premier League 2023, 22nd Match at Mumbai, April 16, 2023 - Full Scorecard
# With Match_id : 1359496
# Fetch data for : LSG vs PBKS, Indian Premier League 2023, 21st Match at Lucknow, April 15, 2023 - Full Scorecard
# With Match_id : 1359495
# Fetch data for : RCB vs DC, Indian Premier League 2023, 20th Match at Bengaluru, April 15, 2023 - Full Scorecard
# With Match_id : 1359494
# Fetch data for : KKR vs SRH, Indian Premier League 2023, 19th Match at Kolkata, April 14, 2023 - Full Scorecard
# With Match_id : 1359493
# Fetch data for : PBKS vs GT, Indian Premier League 2023, 18th Match at Chandigarh, April 13, 2023 - Full Scorecard
# With Match_id : 1359492
# Fetch data for : CSK vs RR, Indian Premier League 2023, 17th Match at Chennai, April 12, 2023 - Full Scorecard
# With Match_id : 1359491
# Fetch data for : DC vs MI, Indian Premier League 2023, 16th Match at Delhi, April 11, 2023 - Full Scorecard
# With Match_id : 1359490
# Fetch data for : RCB vs LSG, Indian Premier League 2023, 15th Match at Bengaluru, April 10, 2023 - Full Scorecard
# With Match_id : 1359489
# Fetch data for : SRH vs PBKS, Indian Premier League 2023, 14th Match at Hyderabad, April 09, 2023 - Full Scorecard
# With Match_id : 1359488
# Fetch data for : GT vs KKR, Indian Premier League 2023, 13th Match at Ahmedabad, April 09, 2023 - Full Scorecard
# With Match_id : 1359487
# Fetch data for : MI vs CSK, Indian Premier League 2023, 12th Match at Mumbai, April 08, 2023 - Full Scorecard
# With Match_id : 1359486
# Fetch data for : RR vs DC, Indian Premier League 2023, 11th Match at Guwahati, April 08, 2023 - Full Scorecard
# With Match_id : 1359485
# Fetch data for : LSG vs SRH, Indian Premier League 2023, 10th Match at Lucknow, April 07, 2023 - Full Scorecard
# With Match_id : 1359484
# Fetch data for : KKR vs RCB, Indian Premier League 2023, 9th Match at Kolkata, April 06, 2023 - Full Scorecard
# With Match_id : 1359483
# Fetch data for : RR vs PBKS, Indian Premier League 2023, 8th Match at Guwahati, April 05, 2023 - Full Scorecard
# With Match_id : 1359482
# Fetch data for : DC vs GT, Indian Premier League 2023, 7th Match at Delhi, April 04, 2023 - Full Scorecard
# With Match_id : 1359481
# Fetch data for : CSK vs LSG, Indian Premier League 2023, 6th Match at Chennai, April 03, 2023 - Full Scorecard
# With Match_id : 1359480
# Fetch data for : RCB vs MI, Indian Premier League 2023, 5th Match at Bengaluru, April 02, 2023 - Full Scorecard
# With Match_id : 1359479
# Fetch data for : SRH vs RR, Indian Premier League 2023, 4th Match at Hyderabad, April 02, 2023 - Full Scorecard
# With Match_id : 1359478
# Fetch data for : LSG vs DC, Indian Premier League 2023, 3rd Match at Lucknow, April 01, 2023 - Full Scorecard
# With Match_id : 1359477
# Fetch data for : PBKS vs KKR, Indian Premier League 2023, 2nd Match at Chandigarh, April 01, 2023 - Full Scorecard
# With Match_id : 1359476
# Fetch data for : GT vs CSK, Indian Premier League 2023, 1st Match at Ahmedabad, March 31, 2023 - Full Scorecard
# With Match_id : 1359475

# %%
batting_1
# Out:
#               BATTING                             R   B     M    4s    6s  \
# 0   Wriddhiman Saha †      c †Dhoni b Chahar     54  39    63     5     1
# 1       Shubman Gill      st †Dhoni b Jadeja     39  20    34     7     0
# 2      Sai Sudharsan         lbw b Pathirana     96  47    58     8     6
# 3   Hardik Pandya (c)               not out      21  12    32     0     2
# 4        Rashid Khan   c Gaikwad b Pathirana      0   2     2     0     0
# ..                ...                    ...    ...  ..   ...   ...   ...
# 6    Ravindra Jadeja      c Shankar b Joseph      1   2     -     0     0
# 7       MS Dhoni (c)†               not out      14   7     -     1     1
# 8   Mitchell Santner                not out       1   3     -     0     0
# 9              Extras      (b 1, lb 6, nb 1)      8      None  None  None
# 10              TOTAL       20 Ov (RR: 8.90)  178/7      None  None  None
#
#         SR match_id
# 0   138.46  1370353
# 1   195.00  1370353
# 2   204.25  1370353
# 3   175.00  1370353
# 4     0.00  1370353
# ..     ...      ...
# 6    50.00  1359475
# 7   200.00  1359475
# 8    33.33  1359475
# 9     None  1359475
# 10    None  1359475
#
# [726 rows x 9 columns]

# %% [markdown]
# -

# %%
14 in batting_1.groupby('match_id').cumcount().add(1).tolist()
# Out:
# False

# %%
14 in batting_2.groupby('match_id').cumcount().add(1).tolist()
# Out:
# False

# %%
batting_1['batting_position'] = batting_1.groupby('match_id').cumcount().add(1)
batting_2['batting_position'] = batting_2.groupby('match_id').cumcount().add(1)

# %%
batting_1[batting_1['BATTING'] == 'Extras']
# Out:
#    BATTING                      R B      M    4s    6s    SR match_id  \
# 5   Extras   (b 1, lb 1, w 2)   4     None  None  None  None  1370353
# 5   Extras  (lb 2, nb 2, w 6)  10     None  None  None  None  1370352
# 9   Extras   (b 8, lb 2, w 6)  16     None  None  None  None  1370351
# 8   Extras  (b 1, lb 2, nb 2)   5     None  None  None  None  1370350
# 7   Extras        (lb 2, w 5)   7     None  None  None  None  1359544
# ..     ...                ...  .. ..   ...   ...   ...   ...      ...
# 9   Extras       (nb 1, w 10)  11     None  None  None  None  1359479
# 7   Extras   (b 5, lb 1, w 2)   8     None  None  None  None  1359478
# 8   Extras   (b 1, lb 2, w 5)   8     None  None  None  None  1359477
# 7   Extras  (lb 1, nb 1, w 2)   4     None  None  None  None  1359476
# 9   Extras  (b 1, lb 6, nb 1)   8     None  None  None  None  1359475
#
#     batting_position
# 5                  6
# 5                  6
# 9                 10
# 8                  9
# 7                  8
# ..               ...
# 9                 10
# 7                  8
# 8                  9
# 7                  8
# 9                 10
#
# [73 rows x 10 columns]

# %%
bowling_1
# Out:
#                 BOWLING  O  M   R  W   ECON  0s 4s 6s WD NB match_id
# 0         Deepak Chahar  4  0  38  1   9.50   5  3  1  0  0  1370353
# 1      Tushar Deshpande  4  0  56  0  14.00   4  7  3  0  0  1370353
# 2    Maheesh Theekshana  4  0  36  0   9.00   8  3  2  0  0  1370353
# 3       Ravindra Jadeja  4  0  38  1   9.50   3  3  1  0  0  1370353
# 4   Matheesha Pathirana  4  0  44  2  11.00   7  4  2  2  0  1370353
# ..                  ... .. ..  .. ..    ...  .. .. .. .. ..      ...
# 1         Hardik Pandya  3  0  28  0   9.33   6  2  2  0  0  1359475
# 2           Josh Little  4  0  41  1  10.25  10  4  3  0  0  1359475
# 3           Rashid Khan  4  0  26  2   6.50  10  2  1  0  0  1359475
# 4        Alzarri Joseph  4  0  33  2   8.25   8  0  3  0  0  1359475
# 5            Yash Dayal  1  0  14  0  14.00   2  0  2  0  0  1359475
#
# [443 rows x 12 columns]

# %%
point_table.head(10)
# Out:
#    TEAM   M   W   L  PT     NRR match_id
# 0    GT  14  10   4  20   0.809  1370353
# 1   CSK  14   8   5  17   0.652  1370353
# 2   LSG  14   8   5  17   0.284  1370353
# 3    MI  14   8   6  16  -0.044  1370353
# 4    RR  14   7   7  14   0.148  1370353
# 5   RCB  14   7   7  14   0.135  1370353
# 6   KKR  14   6   8  12  -0.239  1370353
# 7  PBKS  14   6   8  12  -0.304  1370353
# 8    DC  14   5   9  10  -0.808  1370353
# 9   SRH  14   4  10   8  -0.590  1370353

# %%
point_table.tail(10)
# Out:
#    TEAM   M   W   L  PT     NRR match_id
# 0    GT  14  10   4  20   0.809  1359475
# 1   CSK  14   8   5  17   0.652  1359475
# 2   LSG  14   8   5  17   0.284  1359475
# 3    MI  14   8   6  16  -0.044  1359475
# 4    RR  14   7   7  14   0.148  1359475
# 5   RCB  14   7   7  14   0.135  1359475
# 6   KKR  14   6   8  12  -0.239  1359475
# 7  PBKS  14   6   8  12  -0.304  1359475
# 8    DC  14   5   9  10  -0.808  1359475
# 9   SRH  14   4  10   8  -0.590  1359475

# %% [markdown]
# **Note**
# - **Above** we have total 5 Datasets : batting_1, bowling_1, batting_2, bowling_2, point_table.
# - **batting_1** and **batting_2** can be mergerd bcz we have match_id to partition later if required.
# - Similarly  **bowling_1** and **bowling_2**.
# - **point_table** pointing to same datasets for each_match which is the series overal points.
# ##### So in the below steps we will merge **batting_1** / **batting_2** and **bowling_1** / **bowling_2**.
# ##### For point_table, keep last match records.
# ###### later code will be refined, optimized, and will be available as .py or as a data pipeline. (*Current version of code was a base idea to collect data, and start analytics work.*)

# %%
batting = pd.concat([batting_1, batting_2])
bowling = pd.concat([bowling_1, bowling_2])
point_table = point_table.head(10)

# %%
batting_1.shape, batting_2.shape, batting.shape
# Out:
# ((726, 10), (739, 10), (1465, 10))

# %%
bowling_1.shape, bowling_2.shape, bowling.shape
# Out:
# ((443, 12), (449, 12), (892, 12))

# %%
point_table.shape
# Out:
# (10, 7)

# %%
batting.head()
# Out:
#              BATTING                          R   B   M 4s 6s      SR  \
# 0  Wriddhiman Saha †      c †Dhoni b Chahar  54  39  63  5  1  138.46
# 1      Shubman Gill      st †Dhoni b Jadeja  39  20  34  7  0  195.00
# 2     Sai Sudharsan         lbw b Pathirana  96  47  58  8  6  204.25
# 3  Hardik Pandya (c)               not out   21  12  32  0  2  175.00
# 4       Rashid Khan   c Gaikwad b Pathirana   0   2   2  0  0    0.00
#
#   match_id  batting_position
# 0  1370353                 1
# 1  1370353                 2
# 2  1370353                 3
# 3  1370353                 4
# 4  1370353                 5

# %%
batting.columns = ['batsman', 'out', 'run', 'ball', 'minutes', '4s', '6s', 'sr', 'match_id', 'batting_position']
batting.head()
# Out:
#              batsman                    out run ball minutes 4s 6s      sr  \
# 0  Wriddhiman Saha †      c †Dhoni b Chahar  54   39      63  5  1  138.46
# 1      Shubman Gill      st †Dhoni b Jadeja  39   20      34  7  0  195.00
# 2     Sai Sudharsan         lbw b Pathirana  96   47      58  8  6  204.25
# 3  Hardik Pandya (c)               not out   21   12      32  0  2  175.00
# 4       Rashid Khan   c Gaikwad b Pathirana   0    2       2  0  0    0.00
#
#   match_id  batting_position
# 0  1370353                 1
# 1  1370353                 2
# 2  1370353                 3
# 3  1370353                 4
# 4  1370353                 5

# %%
bowling.head()
# Out:
#                BOWLING  O  M   R  W   ECON 0s 4s 6s WD NB match_id
# 0        Deepak Chahar  4  0  38  1   9.50  5  3  1  0  0  1370353
# 1     Tushar Deshpande  4  0  56  0  14.00  4  7  3  0  0  1370353
# 2   Maheesh Theekshana  4  0  36  0   9.00  8  3  2  0  0  1370353
# 3      Ravindra Jadeja  4  0  38  1   9.50  3  3  1  0  0  1370353
# 4  Matheesha Pathirana  4  0  44  2  11.00  7  4  2  2  0  1370353

# %%
bowling.columns = ['bowling', 'over', 'maiden', 'run', 'wickets', 'economy_rate', '0s', '4s', '6s', 'wide', 'no_ball', 'match_id']
bowling.head()
# Out:
#                bowling over maiden run wickets economy_rate 0s 4s 6s wide  \
# 0        Deepak Chahar    4      0  38       1         9.50  5  3  1    0
# 1     Tushar Deshpande    4      0  56       0        14.00  4  7  3    0
# 2   Maheesh Theekshana    4      0  36       0         9.00  8  3  2    0
# 3      Ravindra Jadeja    4      0  38       1         9.50  3  3  1    0
# 4  Matheesha Pathirana    4      0  44       2        11.00  7  4  2    2
#
#   no_ball match_id
# 0       0  1370353
# 1       0  1370353
# 2       0  1370353
# 3       0  1370353
# 4       0  1370353

# %%
batting.to_csv("ipl_2023_batting.csv", index=False)
print("ipl_2023_batting.csv downloaded successfully !!!")
# Out:
# ipl_2023_batting.csv downloaded successfully !!!

# %%
bowling.to_csv("ipl_2023_bowling.csv", index=False)
print("ipl_2023_bowling.csv downloaded successfully !!!")
# Out:
# ipl_2023_bowling.csv downloaded successfully !!!

# %%
point_table.to_csv("ipl_2023_point_table.csv", index=False)
print("ipl_2023_point_table.csv downloaded successfully !!!")
# Out:
# ipl_2023_point_table.csv downloaded successfully !!!
